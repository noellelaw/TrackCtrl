# %%
#@title Connect to google drive

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CERA Lab/
# !git clone https://github.com/noellelaw/TrackCtrl
# Out:
# /content/drive/.shortcut-targets-by-id/1afxFXhsAmEKRa9x8l8Jf36TKxKhvaj8W/CERA Lab
# fatal: destination path 'TrackCtrl' already exists and is not an empty directory.

# %%
# %cd /content/drive/.shortcut-targets-by-id/1afxFXhsAmEKRa9x8l8Jf36TKxKhvaj8W/CERA Lab/TrackCtrl/
# !pip install pip==23.3.1
# !pip install numpy==1.26.4
# !pip install pytorch-lightning==1.5.10
# !pip install  torchmetrics==0.11.4
# !pip install -r requirements.txt
# Out:
# /content/drive/.shortcut-targets-by-id/1afxFXhsAmEKRa9x8l8Jf36TKxKhvaj8W/CERA Lab/TrackCtrl
# Requirement already satisfied: pip==23.3.1 in /usr/local/lib/python3.11/dist-packages (23.3.1)
# DEPRECATION: pytorch-lightning 1.5.10 has a non-standard dependency specifier torch>=1.7.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (1.26.4)
# DEPRECATION: pytorch-lightning 1.5.10 has a non-standard dependency specifier torch>=1.7.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: pytorch-lightning==1.5.10 in /usr/local/lib/python3.11/dist-packages (1.5.10)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning==1.5.10) (1.26.4)
# Requirement already satisfied: torch>=1.7.* in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning==1.5.10) (2.6.0+cu124)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning==1.5.10) (1.0.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning==1.5.10) (4.67.1)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning==1.5.10) (6.0.2)
# Requirement already satisfied: fsspec!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10) (2025.3.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning==1.5.10) (2.18.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning==1.5.10) (0.11.4)
# Requirement already satisfied: pyDeprecate==0.3.1 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning==1.5.10) (0.3.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning==1.5.10) (24.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning==1.5.10) (4.14.0)
# Requirement already satisfied: setuptools==59.5.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning==1.5.10) (59.5.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10) (3.11.15)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10) (1.73.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10) (3.8.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10) (5.29.5)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.*->pytorch-lightning==1.5.10) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.7.*->pytorch-lightning==1.5.10) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10) (1.20.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning==1.5.10) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10) (3.10)
# DEPRECATION: pytorch-lightning 1.5.10 has a non-standard dependency specifier torch>=1.7.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: torchmetrics==0.11.4 in /usr/local/lib/python3.11/dist-packages (0.11.4)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.11/dist-packages (from torchmetrics==0.11.4) (1.26.4)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from torchmetrics==0.11.4) (2.6.0+cu124)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from torchmetrics==0.11.4) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->torchmetrics==0.11.4) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.1->torchmetrics==0.11.4) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.1->torchmetrics==0.11.4) (3.0.2)
# DEPRECATION: pytorch-lightning 1.5.10 has a non-standard dependency specifier torch>=1.7.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: cartopy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (0.24.1)
# Requirement already satisfied: cdsapi in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (0.7.6)
# Requirement already satisfied: cfgrib in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (0.9.15.0)
# Requirement already satisfied: dask in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (2024.12.1)
# Requirement already satisfied: h5netcdf in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (1.6.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (1.7.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (2.32.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (1.15.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (2025.3.1)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (2.0.8)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (4.11.0.86)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (2.37.0)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (0.6.0)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (1.5.10)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (2.3.0)
# Requirement already satisfied: test-tube in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 19)) (0.7.5)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 20)) (1.46.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 21)) (0.8.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 22)) (4.53.0)
# Requirement already satisfied: webdataset in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 23)) (1.0.2)
# Requirement already satisfied: kornia in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 24)) (0.8.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 25)) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 26)) (0.21.0+cu124)
# Requirement already satisfied: open_clip_torch in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (2.32.0)
# Requirement already satisfied: invisible-watermark in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (0.2.0)
# Requirement already satisfied: streamlit-drawable-canvas in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 29)) (0.9.3)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 30)) (0.11.4)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 31)) (1.0.16)
# Requirement already satisfied: addict in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 32)) (2.4.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 33)) (0.43.0)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 34)) (3.16.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 35)) (0.5.3)
# Requirement already satisfied: basicsr in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 36)) (1.4.2)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from cartopy->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: shapely>=1.8 in /usr/local/lib/python3.11/dist-packages (from cartopy->-r requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from cartopy->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.11/dist-packages (from cartopy->-r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /usr/local/lib/python3.11/dist-packages (from cartopy->-r requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: ecmwf-datastores-client in /usr/local/lib/python3.11/dist-packages (from cdsapi->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from cdsapi->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: attrs>=19.2 in /usr/local/lib/python3.11/dist-packages (from cfgrib->-r requirements.txt (line 3)) (25.3.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from cfgrib->-r requirements.txt (line 3)) (8.2.1)
# Requirement already satisfied: eccodes>=0.9.8 in /usr/local/lib/python3.11/dist-packages (from cfgrib->-r requirements.txt (line 3)) (2.42.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask->-r requirements.txt (line 4)) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask->-r requirements.txt (line 4)) (2025.3.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask->-r requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask->-r requirements.txt (line 4)) (8.7.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from h5netcdf->-r requirements.txt (line 5)) (3.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 6)) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 6)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 6)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: cftime in /usr/local/lib/python3.11/dist-packages (from netcdf4->-r requirements.txt (line 7)) (1.6.4.post1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from netcdf4->-r requirements.txt (line 7)) (2025.6.15)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 9)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 9)) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements.txt (line 10)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements.txt (line 10)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements.txt (line 10)) (2.4.0)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations->-r requirements.txt (line 13)) (2.11.7)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.11/dist-packages (from albumentations->-r requirements.txt (line 13)) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations->-r requirements.txt (line 13)) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.24->albumentations->-r requirements.txt (line 13)) (3.12.5)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.24->albumentations->-r requirements.txt (line 13)) (6.4.9)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->-r requirements.txt (line 17)) (1.0.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->-r requirements.txt (line 17)) (2.18.0)
# Requirement already satisfied: pyDeprecate==0.3.1 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->-r requirements.txt (line 17)) (0.3.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->-r requirements.txt (line 17)) (4.14.0)
# Requirement already satisfied: setuptools==59.5.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->-r requirements.txt (line 17)) (59.5.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf->-r requirements.txt (line 18)) (4.9.3)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 20)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 20)) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 20)) (5.5.2)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 20)) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 20)) (18.1.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 20)) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 20)) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 20)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 20)) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 20)) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r requirements.txt (line 20)) (6.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 22)) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 22)) (0.33.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 22)) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->-r requirements.txt (line 22)) (0.21.2)
# Requirement already satisfied: braceexpand in /usr/local/lib/python3.11/dist-packages (from webdataset->-r requirements.txt (line 23)) (0.1.7)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.11/dist-packages (from kornia->-r requirements.txt (line 24)) (0.1.9)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 25)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->-r requirements.txt (line 25)) (1.3.0)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.11/dist-packages (from open_clip_torch->-r requirements.txt (line 27)) (6.3.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from invisible-watermark->-r requirements.txt (line 28)) (1.8.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.11/dist-packages (from invisible-watermark->-r requirements.txt (line 28)) (4.11.0.86)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->-r requirements.txt (line 33)) (4.3.8)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prettytable->-r requirements.txt (line 34)) (0.2.13)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.11/dist-packages (from basicsr->-r requirements.txt (line 36)) (1.6.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from basicsr->-r requirements.txt (line 36)) (0.25.2)
# Requirement already satisfied: tb-nightly in /usr/local/lib/python3.11/dist-packages (from basicsr->-r requirements.txt (line 36)) (2.20.0a20250703)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 20)) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 20)) (1.45.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.11/dist-packages (from eccodes>=0.9.8->cfgrib->-r requirements.txt (line 3)) (1.17.1)
# Requirement already satisfied: findlibs in /usr/local/lib/python3.11/dist-packages (from eccodes>=0.9.8->cfgrib->-r requirements.txt (line 3)) (0.1.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r requirements.txt (line 17)) (3.11.15)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 20)) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers->-r requirements.txt (line 22)) (1.1.5)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask->-r requirements.txt (line 4)) (3.23.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->-r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->-r requirements.txt (line 13)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations->-r requirements.txt (line 13)) (0.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->-r requirements.txt (line 25)) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 17)) (1.73.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 17)) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 17)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->-r requirements.txt (line 17)) (3.1.3)
# Requirement already satisfied: multiurl>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from ecmwf-datastores-client->cdsapi->-r requirements.txt (line 2)) (0.3.5)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->basicsr->-r requirements.txt (line 36)) (2025.6.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->basicsr->-r requirements.txt (line 36)) (0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r requirements.txt (line 17)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r requirements.txt (line 17)) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r requirements.txt (line 17)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r requirements.txt (line 17)) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r requirements.txt (line 17)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r requirements.txt (line 17)) (1.20.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 20)) (5.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 20)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 20)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 20)) (0.26.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi->eccodes>=0.9.8->cfgrib->-r requirements.txt (line 3)) (2.22)
# DEPRECATION: pytorch-lightning 1.5.10 has a non-standard dependency specifier torch>=1.7.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import torch
import pytorch_lightning as pl
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from dataset import HurricaneTrackDataset
from cldm.logger import ImageLogger
from cldm.model import create_model, load_state_dict
import torch
import einops
import random
from pytorch_lightning import seed_everything
import matplotlib.pyplot as plt

from cldm.ddim_hacked import DDIMSampler
import numpy as np

# %%
def run_inference(model, dataloader, ddim_sampler, device, steps=50, strength=1.0, scale=9.0, eta=0.0, guess_mode=False, seed=-1):
    model.eval()
    model.to(device)

    all_predictions = []
    all_inputs = []
    all_targets = []
    all_prompts = []

    with torch.no_grad():
        for batch in dataloader:
            hint = batch['hint']
            target = batch['jpg']  # true track (ground truth)
            prompts = batch['txt']
            num_samples = hint.shape[0]

            # Ensure channels-first
            if hint.ndim == 4 and hint.shape[-1] in [1, 3]:
                hint = einops.rearrange(hint, 'b h w c -> b c h w')

            hint = hint.float().to(device) / 255.0 if hint.max() > 1.0 else hint.float().to(device)

            control = hint.clone()

            if seed == -1:
                seed = random.randint(0, 65535)
            seed_everything(seed)

            cond = {
                "c_concat": [control],
                "c_crossattn": [model.get_learned_conditioning([p for p in prompts])]
            }
            un_cond = {
                "c_concat": None if guess_mode else [control],
                "c_crossattn": [model.get_learned_conditioning([""] * num_samples)]
            }

            _, _, H, W = control.shape
            latent_shape = (4, H // 8, W // 8)

            model.control_scales = (
                [strength * (0.825 ** float(12 - i)) for i in range(13)] if guess_mode else [strength] * 13
            )

            samples, intermediates = ddim_sampler.sample(
                steps, num_samples, latent_shape, cond, device=device, verbose=False, eta=eta,
                unconditional_guidance_scale=scale,
                unconditional_conditioning=un_cond
            )

            x_samples = model.decode_first_stage(samples)
            x_samples = (einops.rearrange(x_samples, 'b c h w -> b h w c') * 127.5 + 127.5)
            x_samples = x_samples.cpu().numpy().clip(0, 255).astype('uint8')

            all_predictions.append(x_samples)
            all_inputs.append(hint.cpu())
            all_targets.append(target.cpu())
            all_prompts.extend(prompts)

            break  # Remove to process all batches

    all_predictions = np.concatenate(all_predictions, axis=0)
    return all_inputs[0], all_targets[0], all_predictions, all_prompts


def plot_inference_results(inputs, targets, predictions, prompts):
    batch_size = predictions.shape[0]
    for i in range(batch_size):
        fig, axs = plt.subplots(1, 3, figsize=(18, 5))

        # Input hint
        hint_img = einops.rearrange(inputs[i], 'c h w -> h w c').numpy()
        axs[0].imshow(hint_img)
        axs[0].set_title('Input Hint (Reanalysis)')
        axs[0].axis('off')

        # Ground truth
        target_img = targets[i].numpy()
        axs[1].imshow(target_img)
        axs[1].set_title('Expected Track (Ground Truth)')
        axs[1].axis('off')

        # Prediction
        axs[2].imshow(predictions[i])
        axs[2].set_title('Predicted Output')
        axs[2].axis('off')

        plt.suptitle(prompts[i])
        plt.show()

        # Print summary of expected values
        print(f"\nPrompt: {prompts[i]}")
        print(f"Expected (Target) min/max per channel: {[target_img[..., c].min() for c in range(3)]} / {[target_img[..., c].max() for c in range(3)]}")
        print(f"Predicted min/max: {predictions[i].min()} / {predictions[i].max()}")


def main():
    resume_path = '/content/drive/MyDrive/CERA Lab/TrackCtrl/lightning_logs/version_4/checkpoints/epoch=0-step=719.ckpt'
    batch_size = 4
    learning_rate = 1e-5
    sd_locked = True
    only_mid_control = False

    model = create_model('./models/cldm_v15.yaml').cpu()
    model.load_state_dict(load_state_dict(resume_path, location='cpu'), strict=False)
    model.learning_rate = learning_rate
    model.sd_locked = sd_locked
    model.only_mid_control = only_mid_control
    ddim_sampler = DDIMSampler(model)

    csv_path = '/content/drive/MyDrive/CERA Lab/Data/era5_storms/hurdat2_north_atlantic_val.csv'
    nc_path = '/content/drive/MyDrive/CERA Lab/Data/era5_storms/2021.nc'
    dataset = HurricaneTrackDataset(csv_path, nc_path)
    dataloader = DataLoader(dataset, num_workers=0, batch_size=batch_size, shuffle=False)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    inputs, targets, predictions, prompts = run_inference(
        model=model,
        dataloader=dataloader,
        ddim_sampler=ddim_sampler,
        device=device,
        steps=500,
        strength=1.0,
        scale=9.0,
        eta=0.0,
        guess_mode=False
    )

    plot_inference_results(inputs, targets, predictions, prompts)

# %%
main()
# Out:
# ControlLDM: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Loaded model config from [./models/cldm_v15.yaml]
# Loaded state_dict from [/content/drive/MyDrive/CERA Lab/TrackCtrl/lightning_logs/version_4/checkpoints/epoch=0-step=719.ckpt]
# INFO:pytorch_lightning.utilities.seed:Global seed set to 2934
# Data shape for DDIM sampling is (4, 4, 32, 32), eta 0.0
# Running DDIM Sampling with 500 timesteps
# DDIM Sampler:  79%|███████▉  | 397/500 [01:09<00:18,  5.51it/s]

# %%
import torch
import gc
gc.collect()
torch.cuda.empty_cache()
